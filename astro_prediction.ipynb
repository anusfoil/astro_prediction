# %%
"""
Copyright (C) 2023 Huan Zhang - All Rights Reserved
You may use, distribute and modify this code under the
terms of the Creative Commons license.
"""
import sys
sys.path.append("TkAstroDb-master")
sys.path.append("TkAstroDb-master/Scripts")
import xml.etree.ElementTree as ET
import hook
from TkAstroDb.Scripts.utilities import *

astro_data_path = "data/adb_export_sample.xml"
astro_data_path = "data/c_sample.xml"

# %%
adb, _ = from_xml(astro_data_path)

# %% [markdown]
# # TODO: Analyzing adb data
#
# Extract information (predictive labels) that you find interesting such as vocation, health status..
#
# Feel free to do some statistical visualization of the labels in database.

# %%
adb
# Out:
# [[2,
#   'Cardano, Girolamo',
#   'M',
#   'B',
#   '24 September 1501 Jul.Cal. (4 Oct 1501 greg.)',
#   '18:29',
#   '2269565.244676',
#   '45n10',
#   '9e10',
#   'Pavia',
#   'Italy',
#   'https://www.astro.com/astro-databank/Cardano,_Girolamo',
#   [('210', 'Family : Parenting : Kids -Traumatic event'),
#    ('267', 'Passions : Criminal Perpetrator : Civil/ Political'),
#    ('469', 'Vocation : Medical : Physician'),
#    ('483', 'Vocation : Occult Fields : Astrologer'),
#    ('622', 'Vocation : Writers : Astrology'),
#    ('619', 'Notable : Famous : Top 5% of Profession'),
#    ('633', 'Notable : Book Collection : Occult/ Misc. Collection')]],
#  [6,
#   'Cardano, Giovanni Battista',
#   'M',
#   'C',
#   '14 May 1534 Jul.Cal. (24 May 1534 greg.)',
#   '20:26',
#   '2281485.325833',
#   '45n28',
#   '9e12',
#   'Milan',
#   'Italy',
#   'https://www.astro.com/astro-databank/Cardano,_Giovanni_Battista',
#   [('288', 'Passions : Criminal Perpetrator : Executed'),
# ...

# %% [markdown]
# # TODO: Obtain Astrological features by calculation
#
# In the adb entry, the birth date and time, as well as location, will be recorded. You will have to apply the kerykeion package to calculate the chart information. Refer to the documentation here: https://pypi.org/project/kerykeion/

# %% [markdown]
# # TODO: Represent the chart information into machine-learnable format
#
# There are loads of information from a person's birthchart, which should be given to you by the Kerykeon package:
# - Stars: Sun, Moon, Mercury, Venus...
# - Signs: Aries, Taurus... (12)
#     - Note that signs have other feature properties like Elements (water, earth, fire, air) and Mode (cardinal, fixed, mutable).
# - Houses: (12 of them)
# - Aspects: How the stars relates to each other.
#
# Feel free to try representing their relationship as graph, or try using the birthcart as image (Kerykeion package seems to provide that), or using token sequence to embed these information.
